# %% [markdown]
# # 02 - Feature Engineering
# ---
# **Mục tiêu:** Tạo các features mới để cải thiện model
#
# **Nội dung:**
# - Tạo features từ thời gian (hour, day_of_week)
# - Rolling windows features
# - Distance features
# - Aggregation features
# - Feature scaling/normalization

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

import sys
sys.path.append('../')
from src.features.engineering import *

# %% [markdown]
# ## TODO: Thêm các bước feature engineering của bạn ở đây
